# %%
# import pandas
import pandas as pd

# %%
# read csv

df = pd.read_csv('./CSVS/bluepair.csv')

df2 = pd.read_csv('./CSVS/hardpair.csv')

df3 = pd.read_csv('./CSVS/semisortpairings.csv')

df4 = pd.read_csv('./CSVS/semihardpair1.csv')

df5 = pd.read_csv('./CSVS/semihardpair2.csv')

df6 = pd.read_csv('./CSVS/semihardpairing3.csv')

df7 = pd.read_csv('./CSVS/softcheese.csv')



df.head()
# Out:
#          Variety       Wines     Beverages            Fruits/Vegetables  \
# 0    Blue Cheese     Dessert   Apple juice                       Apples
# 1    Blue Cheese         Red        Coffee                      Carrots
# 2    Blue Cheese   Sparkling         Gin                         Celery
# 3    Blue Cheese         NaN      Lambic             Dried  cranberries
# 4    Blue Cheese         NaN   Pear nectar                    Cucumbers
# 5    Blue Cheese         NaN         Stout                        Pears
# 6    Blue Cheese         NaN           NaN                          NaN
# 7   Creamy Blue      Dessert   Apple juice   Apricots (fresh or dried)
# 8   Creamy Blue          Red        Coffee                       Celery
# 9   Creamy Blue    Sparkling         Gin                      Cucumbers
# 10  Creamy Blue          NaN      Lambic                           Figs
# 11  Creamy Blue          NaN   Pear nectar                        Pears
# ...

# %%
# check csv df2
df2.head()
# Out:
#        Variety        Wines    Beverages Fruits/Vegetables  \
# 0  Appenzeller   Fruity red         Bock            Apples
# 1  Appenzeller        White   Light beer           Carrots
# 2  Appenzeller          NaN          NaN         Cucumbers
# 3  Appenzeller          NaN          NaN           Melons
# 4  Appenzeller          NaN          NaN      Strawberries
#
#          Breads/Crackers Condiments/Nuts   Meats/Fish
# 0           Raisin bread         Almonds         Ham
# 1        Sourdough bread    Fruit butter      Poultry
# 2  Whole grain crackers          Pickles   Prosciutto
# 3                    NaN             NaN         Pork
# 4                    NaN             NaN          NaN

# %%
# check csv df3
df3.head()
# Out:
#    Variety        Wines Beverages Fruits/Vegetables  Breads/Crackers  \
# 0  Havarti   Fruity red   Pilsner           Carrots      Melba toast
# 1  Havarti    Light red     Stout         Cucumbers        Rye bread
# 2  Havarti          NaN       NaN             Dates   Water crackers
# 3  Havarti          NaN       NaN             Pears              NaN
# 4  Havarti          NaN       NaN             Plums              NaN
#
#          Condiments/Nuts      Meats/Fish
# 0                Almonds         Poultry
# 1                Chutney         Seafood
# 2   Roasted red peppers    Smoked turkey
# 3                    NaN             NaN
# 4                    NaN             NaN

# %%
# check csv df4
df4.head()
# Out:
#     Variety          Wines            Beverages Fruits/Vegetables  \
# 0  American   Fruity white          Apple juice            Apples
# 1  American      Light red   White grape juice           Broccoli
# 2  American            NaN                  NaN           Carrots
# 3  American            NaN                  NaN            Celery
# 4  American            NaN                  NaN            Grapes
#
#    Breads/Crackers Condiments/Nuts   Meats/Fish
# 0         Pretzels         Mustard          Ham
# 1   Water crackers         Pickles      Bologna
# 2   Wheat crackers         Raisins   Casseroles
# 3              NaN             NaN          NaN
# 4              NaN             NaN          NaN

# %%
# check csv df5
df5.head()
# Out:
#        Variety          Wines Beverages    Fruits/Vegetables  Breads/Crackers  \
# 0  Edam (mild)     Fruity red    Lager               Carrots       Dark bread
# 1  Edam (mild)   Fruity white     Stout               Celery        Flatbread
# 2  Edam (mild)            NaN       NaN            Cucumbers        Rye bread
# 3  Edam (mild)            NaN       NaN   Dried  cranberries   Wheat crackers
# 4  Edam (mild)            NaN       NaN              Peaches              NaN
#
#   Condiments/Nuts   Meats/Fish
# 0         Almonds         Beef
# 1         Chutney    Cold cuts
# 2         Mustard         Ham
# 3             NaN   Prosciutto
# 4             NaN         Pork

# %%
# check csv df6
df6.head()
# Out:
#     Variety          Wines  Beverages Fruits/Vegetables  Breads/Crackers  \
# 0  Muenster   Fruity white   Cider               Apples       Dark bread
# 1  Muenster      Light red      Lager      Bell peppers        Nut bread
# 2  Muenster    Spicy white    Pilsner            Grapes   Wheat crackers
# 3  Muenster            NaN        NaN             Pears              NaN
# 4  Muenster            NaN        NaN          Radishes              NaN
#
#   Condiments/Nuts      Meats/Fish
# 0         Chutney         Sausage
# 1         Mustard         Seafood
# 2         Pickles   Smoked turkey
# 3         Walnuts             NaN
# 4             NaN             NaN

# %%
# check csv df7
df7.head()
# Out:
#           Variety        Wines            Beverages Fruits/Vegetables  \
# 0  Brie/Camembert   Fruity red               Cider             Apples
# 1  Brie/Camembert    Sparkling   White grape juice            Carrots
# 2  Brie/Camembert          NaN  Lambic-style  beer        Dried fruit
# 3  Brie/Camembert          NaN                  NaN         Mushrooms
# 4  Brie/Camembert          NaN                  NaN             Pears
#
#          Breads/Crackers Condiments/Nuts Meats/Fish
# 0           Crusty bread         Almonds       Beef
# 1            Melba toast         Chutney      Lamb
# 2   Water table crackers   Sweet pickles    Seafood
# 3                    NaN             NaN    Poultry
# 4                    NaN             NaN        NaN

# %%
# concat df and df2
concat_1 = pd.concat([df, df2])
concat_1
# Out:
#         Variety       Wines     Beverages    Fruits/Vegetables  \
# 0   Blue Cheese     Dessert   Apple juice               Apples
# 1   Blue Cheese         Red        Coffee              Carrots
# 2   Blue Cheese   Sparkling         Gin                 Celery
# 3   Blue Cheese         NaN      Lambic     Dried  cranberries
# 4   Blue Cheese         NaN   Pear nectar            Cucumbers
# ..          ...         ...           ...                  ...
# 25     Romano           NaN           NaN                 Figs
# 26     Romano           NaN           NaN                Pears
# 27     Romano           NaN           NaN             Tomatoes
# 28     Romano           NaN           NaN      Zucchini dishes
# 29     Romano           NaN           NaN                  NaN
#
#           Breads/Crackers Condiments/Nuts   Meats/Fish Wines      Beverages
# 0            Crusty bread    Black olives         Beef   NaN            NaN
# ...

# %%
# concat df3 and df4
concat_2 = pd.concat([df3, df4])
concat_2
# Out:
#              Variety            Wines               Beverages  \
# 0            Havarti       Fruity red                 Pilsner
# 1            Havarti        Light red                   Stout
# 2            Havarti              NaN                     NaN
# 3            Havarti              NaN                     NaN
# 4            Havarti              NaN                     NaN
# 5            Havarti              NaN                     NaN
# 6          Limburger   Brut sparkling                    Bock
# 7          Limburger            White          India pale ale
# 8          Limburger              NaN                     NaN
# 9          Limburger              NaN                     NaN
# 10     Monterey Jack         Aged red    Cran-raspberry juice
# 11     Monterey Jack     Fruity white                 Lambic
# 12     Monterey Jack              NaN            Tomato juice
# 13     Monterey Jack              NaN                     NaN
# ...

# %%
# concat df, df2, df3, df4
cc = pd.concat([concat_1, concat_2])
cc
# Out:
#              Variety       Wines     Beverages    Fruits/Vegetables  \
# 0        Blue Cheese     Dessert   Apple juice               Apples
# 1        Blue Cheese         Red        Coffee              Carrots
# 2        Blue Cheese   Sparkling         Gin                 Celery
# 3        Blue Cheese         NaN      Lambic     Dried  cranberries
# 4        Blue Cheese         NaN   Pear nectar            Cucumbers
# ..               ...         ...           ...                  ...
# 20  Colby/Colby Jack         NaN           NaN          Red peppers
# 21  Colby/Colby Jack         NaN           NaN         Strawberries
# 22  Colby/Colby Jack         NaN           NaN             Tomatoes
# 23  Colby/Colby Jack         NaN           NaN              Melons
# 24               NaN         NaN           NaN               Onions
#
#           Breads/Crackers     Condiments/Nuts       Meats/Fish Wines  \
# 0            Crusty bread        Black olives             Beef   NaN
# ...

# %%
# concat first four (cc) and df7
concat_3 = pd.concat([cc, df7])
concat_3
# Out:
#          Variety       Wines     Beverages    Fruits/Vegetables  \
# 0    Blue Cheese     Dessert   Apple juice               Apples
# 1    Blue Cheese         Red        Coffee              Carrots
# 2    Blue Cheese   Sparkling         Gin                 Celery
# 3    Blue Cheese         NaN      Lambic     Dried  cranberries
# 4    Blue Cheese         NaN   Pear nectar            Cucumbers
# ..           ...         ...           ...                  ...
# 24  Queso Fresco         NaN           NaN        Citrus fruits
# 25  Queso Fresco         NaN           NaN             Avocados
# 26  Queso Fresco         NaN           NaN              Papayas
# 27  Queso Fresco         NaN           NaN              Mangos
# 28  Queso Fresco         NaN           NaN             Tomatoes
#
#           Breads/Crackers Condiments/Nuts Meats/Fish     Wines Beverages
# 0            Crusty bread    Black olives       Beef       NaN       NaN
# ...

# %%
# concant df5 and df6
concat_4 = pd.concat([df5, df6])
concat_4.head()
# Out:
#        Variety          Wines Beverages    Fruits/Vegetables  Breads/Crackers  \
# 0  Edam (mild)     Fruity red    Lager               Carrots       Dark bread
# 1  Edam (mild)   Fruity white     Stout               Celery        Flatbread
# 2  Edam (mild)            NaN       NaN            Cucumbers        Rye bread
# 3  Edam (mild)            NaN       NaN   Dried  cranberries   Wheat crackers
# 4  Edam (mild)            NaN       NaN              Peaches              NaN
#
#   Condiments/Nuts   Meats/Fish
# 0         Almonds         Beef
# 1         Chutney    Cold cuts
# 2         Mustard         Ham
# 3             NaN   Prosciutto
# 4             NaN         Pork

# %%
# concat all
final = pd.concat([concat_3, concat_4])
final
# Out:
#         Variety       Wines     Beverages    Fruits/Vegetables  \
# 0   Blue Cheese     Dessert   Apple juice               Apples
# 1   Blue Cheese         Red        Coffee              Carrots
# 2   Blue Cheese   Sparkling         Gin                 Celery
# 3   Blue Cheese         NaN      Lambic     Dried  cranberries
# 4   Blue Cheese         NaN   Pear nectar            Cucumbers
# ..          ...         ...           ...                  ...
# 13        Swiss         NaN           NaN         Bell peppers
# 14        Swiss         NaN           NaN            Cherries
# 15        Swiss         NaN           NaN            Mushrooms
# 16        Swiss         NaN           NaN       Potato dishes
# 17        Swiss         NaN           NaN               Grapes
#
#           Breads/Crackers Condiments/Nuts  Meats/Fish      Wines  \
# 0            Crusty bread    Black olives        Beef        NaN
# 1               Nut bread          Honey        Fish         NaN
# ...

# %%
# turn into a CSV
final.to_csv('final_cheeseboard.csv', index=False)
